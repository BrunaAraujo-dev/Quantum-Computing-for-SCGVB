# %%
#Computing w_1

# %%
import numpy as np
from qiskit.quantum_info import SparsePauliOp

# Define the w_1 to w_6 terms using SparsePauliOp
# Pauli operators are represented by strings, and the real or complex coefficients are provided separately

# w_1 term definitions using SparsePauliOp
term1_w1 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.234187009655),
    ('ZZZZZYII', 1j * 0.234187009655),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.5),
    ('ZZZZZZZY', 1j * 0.5)
])

term2_w1 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.5),
    ('ZZZZZYII', 1j * 0.5),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.234187009655),
    ('ZZZZZZZY', 1j * 0.234187009655)
])

term3_w1 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.234187009655),
    ('YIIIIIII', 1j * 0.234187009655),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.5),
    ('ZZYIIIII', 1j * 0.5),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

term4_w1 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.5),
    ('YIIIIIII', 1j * 0.5),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.234187009655),
    ('ZZYIIIII', 1j * 0.234187009655),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

# Function to compute the product of all terms
def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4
product_w1_qiskit = pauli_op_product([term1_w1, term2_w1, term3_w1, term4_w1])

# Print the resulting product as a sum of terms
print("Product of Pauli operators with coefficients:")
for label, coeff in product_w1_qiskit.to_list():
    print(f"{coeff} * {label}")

# Save the result to a text file
with open('pauli_product_output_w1.txt', 'w') as f:
    for label, coeff in product_w1_qiskit.to_list():
        f.write(f"{coeff} * {label}\n")
# Out:
# Product of Pauli operators with coefficients:
# (0.012711216747293252+0j) * IIIIIIII
# (0.012711216747293252-0j) * ZIIIIIII
# (-0+0.008376146782924157j) * YXIIIIII
# (-0.008376146782924157+0j) * YYIIIIII
# (-0+0.005953603678250325j) * YZXIIIII
# (-0.005953603678250325+0j) * YZYIIIII
# (-0+0.008376146782924157j) * YZZXIIII
# (-0.008376146782924157+0j) * YZZYIIII
# (-0.012711216747293252+0j) * ZIIIIIII
# (-0.012711216747293252+0j) * IIIIIIII
# (0.008376146782924157-0j) * XXIIIIII
# 0.008376146782924157j * XYIIIIII
# (0.005953603678250325-0j) * XZXIIIII
# 0.005953603678250325j * XZYIIIII
# (0.008376146782924157-0j) * XZZXIIII
# 0.008376146782924157j * XZZYIIII
# -0.01788345731743136j * YXIIIIII
# (-0.01788345731743136+0j) * XXIIIIII
# (0.011784431534366029+0j) * IIIIIIII
# (0.011784431534366029-0j) * IZIIIIII
# (-0+0.008376146782924157j) * IYXIIIII
# (-0.008376146782924157+0j) * IYYIIIII
# (-0+0.011784431534366029j) * IYZXIIII
# (-0.011784431534366029+0j) * IYZYIIII
# ...

# %%
import numpy as np
from qiskit.quantum_info import SparsePauliOp

# Define the w_1 to w_6 terms using SparsePauliOp
# Pauli operators are represented by strings, and the real or complex coefficients are provided separately

# w_1 term definitions using SparsePauliOp
term1_w1 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.234187009655),
    ('ZZZZZYII', 1j * 0.234187009655),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.5),
    ('ZZZZZZZY', 1j * 0.5)
])

term2_w1 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.5),
    ('ZZZZZYII', 1j * 0.5),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.234187009655),
    ('ZZZZZZZY', 1j * 0.234187009655)
])

term3_w1 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.234187009655),
    ('YIIIIIII', 1j * 0.234187009655),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.5),
    ('ZZYIIIII', 1j * 0.5),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

term4_w1 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.5),
    ('YIIIIIII', 1j * 0.5),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.234187009655),
    ('ZZYIIIII', 1j * 0.234187009655),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

# Function to compute the product of all terms
def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4
product_w1_qiskit = pauli_op_product([term1_w1, term2_w1, term3_w1, term4_w1])

# Prepare the sum as a string format
sum_string = ""
for label, coeff in product_w1_qiskit.to_list():
    # Add each term to the sum with its coefficient
    sum_string += f"({coeff}) * {label} + "

# Remove the trailing " + " from the last term
sum_string = sum_string.rstrip(' + ')

# Print the resulting product as a sum of terms
print("Product of Pauli operators as a sum of terms:")
print(sum_string)

# Save the result to a text file
with open('pauli_product_sum_output_w1_.txt', 'w') as f:
    f.write(sum_string)
# Out:
# Product of Pauli operators as a sum of terms:
# ...

# %%
#Compute w_2

# %%
import numpy as np
from qiskit.quantum_info import SparsePauliOp

# Define the w_2 terms using SparsePauliOp
# Pauli operators are represented by strings, and the real or complex coefficients are provided separately

# w_2 term definitions using SparsePauliOp
term1_w2 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.234187009655),
    ('ZZZZYIII', 1j * 0.234187009655),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.5),
    ('ZZZZZZYI', 1j * 0.5),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term2_w2 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.5),
    ('ZZZZZYII', 1j * 0.5),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.234187009655),
    ('ZZZZZZZY', 1j * 0.234187009655)
])

term3_w2 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.234187009655),
    ('ZYIIIIII', 1j * 0.234187009655),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.5),
    ('ZZZYIIII', 1j * 0.5)
])

term4_w2 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.5),
    ('YIIIIIII', 1j * 0.5),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.234187009655),
    ('ZZYIIIII', 1j * 0.234187009655),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

# Function to compute the product of all terms
def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4 for w_2
product_w2_qiskit = pauli_op_product([term1_w2, term2_w2, term3_w2, term4_w2])

# Prepare the sum as a string format
sum_string_w2 = ""
for label, coeff in product_w2_qiskit.to_list():
    # Add each term to the sum with its coefficient
    sum_string_w2 += f"({coeff}) * {label} + "

# Remove the trailing " + " from the last term
sum_string_w2 = sum_string_w2.rstrip(' + ')

# Print the resulting product as a sum of terms
print("Product of Pauli operators as a sum of terms for w_2:")
print(sum_string_w2)

# Save the result to a text file
with open('pauli_product_sum_output_w2.txt', 'w') as f:
    f.write(sum_string_w2)
# Out:
# Product of Pauli operators as a sum of terms for w_2:
# ...

# %%
import numpy as np
from qiskit.quantum_info import SparsePauliOp

# Define the w_1 to w_6 terms using SparsePauliOp
# Pauli operators are represented by strings, and the real or complex coefficients are provided separately


# w_2 term definitions using SparsePauliOp
term1_w2 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.234187009655),
    ('ZZZZYIII', 1j * 0.234187009655),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.5),
    ('ZZZZZZYI', 1j * 0.5),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term2_w2 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.5),
    ('ZZZZZYII', 1j * 0.5),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.234187009655),
    ('ZZZZZZZY', 1j * 0.234187009655)
])

term3_w2 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.234187009655),
    ('ZYIIIIII', 1j * 0.234187009655),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.5),
    ('ZZZYIIII', 1j * 0.5)
])

term4_w2 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.5),
    ('YIIIIIII', 1j * 0.5),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.234187009655),
    ('ZZYIIIII', 1j * 0.234187009655),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

# Function to compute the product of all terms
def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4
product_w2_qiskit = pauli_op_product([term1_w2, term2_w2, term3_w2, term4_w2])

# Print the resulting product as a sum of terms
print("Product of Pauli operators with coefficients for w2:")
for label, coeff in product_w2_qiskit.to_list():
    print(f"{coeff} * {label}")

# Save the result to a text file
with open('pauli_product_output_w2.txt', 'w') as f:
    for label, coeff in product_w2_qiskit.to_list():
        f.write(f"{coeff} * {label}\n")
# Out:
# Product of Pauli operators with coefficients for w2:
# (0.012711216747293252+0j) * IIIIIIII
# (0.012711216747293252-0j) * ZIIIIIII
# (-0+0.008376146782924157j) * YXIIIIII
# (-0.008376146782924157+0j) * YYIIIIII
# (-0+0.005953603678250325j) * YZXIIIII
# (-0.005953603678250325+0j) * YZYIIIII
# (-0+0.008376146782924157j) * YZZXIIII
# (-0.008376146782924157+0j) * YZZYIIII
# (-0.012711216747293252+0j) * ZIIIIIII
# (-0.012711216747293252+0j) * IIIIIIII
# (0.008376146782924157-0j) * XXIIIIII
# 0.008376146782924157j * XYIIIIII
# (0.005953603678250325-0j) * XZXIIIII
# 0.005953603678250325j * XZYIIIII
# (0.008376146782924157-0j) * XZZXIIII
# 0.008376146782924157j * XZZYIIII
# -0.009034887847954212j * YXIIIIII
# (-0.009034887847954212+0j) * XXIIIIII
# (0.005953603678250325+0j) * IIIIIIII
# (0.005953603678250325-0j) * IZIIIIII
# (-0+0.004231706735361391j) * IYXIIIII
# (-0.004231706735361391+0j) * IYYIIIII
# (-0+0.005953603678250325j) * IYZXIIII
# (-0.005953603678250325+0j) * IYZYIIII
# ...

# %%
# computing for w3

# %%
import numpy as np
from qiskit.quantum_info import SparsePauliOp

# Define the w_3 terms using SparsePauliOp
# Pauli operators are represented by strings, and the real or complex coefficients are provided separately

# w_3 term definitions using SparsePauliOp
term1_w3 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.234187009655),
    ('ZZZZZYII', 1j * 0.234187009655),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.5),
    ('ZZZZZZZY', 1j * 0.5)
])

term2_w3 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.5),
    ('ZZZZYIII', 1j * 0.5),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.234187009655),
    ('ZZZZZZYI', 1j * 0.234187009655),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term3_w3 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.234187009655),
    ('YIIIIIII', 1j * 0.234187009655),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.5),
    ('ZZYIIIII', 1j * 0.5),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

term4_w3 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.5),
    ('ZYIIIIII', 1j * 0.5),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.234187009655),
    ('ZZZYIIII', 1j * 0.234187009655)
])

# Function to compute the product of all terms
def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4 for w_3
product_w3_qiskit = pauli_op_product([term1_w3, term2_w3, term3_w3, term4_w3])

# Prepare the sum as a string format
sum_string_w3 = ""
for label, coeff in product_w3_qiskit.to_list():
    # Add each term to the sum with its coefficient
    sum_string_w3 += f"({coeff}) * {label} + "

# Remove the trailing " + " from the last term
sum_string_w3 = sum_string_w3.rstrip(' + ')

# Print the resulting product as a sum of terms
print("Product of Pauli operators as a sum of terms for w_3:")
print(sum_string_w3)

# Save the result to a text file
with open('pauli_product_sum_output_w3.txt', 'w') as f:
    f.write(sum_string_w3)
# Out:
# Product of Pauli operators as a sum of terms for w_3:
# ...

# %%
term1_w3 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.234187009655),
    ('ZZZZZYII', 1j * 0.234187009655),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.5),
    ('ZZZZZZZY', 1j * 0.5)
])

term2_w3 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.5),
    ('ZZZZYIII', 1j * 0.5),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.234187009655),
    ('ZZZZZZYI', 1j * 0.234187009655),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term3_w3 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.234187009655),
    ('YIIIIIII', 1j * 0.234187009655),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.5),
    ('ZZYIIIII', 1j * 0.5),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

term4_w3 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.5),
    ('ZYIIIIII', 1j * 0.5),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.234187009655),
    ('ZZZYIIII', 1j * 0.234187009655)
])




def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4
product_w3_qiskit = pauli_op_product([term1_w3, term2_w3, term3_w3, term4_w3])

# Print the resulting product as a sum of terms
print("Product of Pauli operators with coefficients for w3:")
for label, coeff in product_w3_qiskit.to_list():
    print(f"{coeff} * {label}")

# Save the result to a text file
with open('pauli_product_output_w3.txt', 'w') as f:
    for label, coeff in product_w3_qiskit.to_list():
        f.write(f"{coeff} * {label}\n")
# Out:
# Product of Pauli operators with coefficients for w3:
# (0.012711216747293252+0j) * IIIIIIII
# (0.012711216747293252-0j) * ZIIIIIII
# (-0+0.019289899685862685j) * YXIIIIII
# (-0.019289899685862685+0j) * YYIIIIII
# (-0+0.012711216747293252j) * YZXIIIII
# (-0.012711216747293252+0j) * YZYIIIII
# (-0+0.009034887847954212j) * YZZXIIII
# (-0.009034887847954212+0j) * YZZYIIII
# (-0.012711216747293252+0j) * ZIIIIIII
# (-0.012711216747293252+0j) * IIIIIIII
# (0.019289899685862685-0j) * XXIIIIII
# 0.019289899685862685j * XYIIIIII
# (0.012711216747293252-0j) * XZXIIIII
# 0.012711216747293252j * XZYIIIII
# (0.009034887847954212-0j) * XZZXIIII
# 0.009034887847954212j * XZZYIIII
# -0.01788345731743136j * YXIIIIII
# (-0.01788345731743136+0j) * XXIIIIII
# (0.0271390303971582+0j) * IIIIIIII
# (0.0271390303971582-0j) * IZIIIIII
# (-0+0.01788345731743136j) * IYXIIIII
# (-0.01788345731743136+0j) * IYYIIIII
# (-0+0.012711216747293252j) * IYZXIIII
# (-0.012711216747293252+0j) * IYZYIIII
# ...

# %%
# Simplifying w_4

# %%
import numpy as np
from qiskit.quantum_info import SparsePauliOp


# Pauli operators are represented by strings, and the real or complex coefficients are provided separately

# w_4 term definitions using SparsePauliOp
term1_w4 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.234187009655),
    ('ZZZZYIII', 1j * 0.234187009655),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.5),
    ('ZZZZZZYI', 1j * 0.5),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term2_w4 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.5),
    ('ZZZZYIII', 1j * 0.5),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.234187009655),
    ('ZZZZZZYI', 1j * 0.234187009655),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term3_w4 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.234187009655),
    ('ZYIIIIII', 1j * 0.234187009655),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.5),
    ('ZZZYIIII', 1j * 0.5)
])

term4_w4 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.5),
    ('ZYIIIIII', 1j * 0.5),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.234187009655),
    ('ZZZYIIII', 1j * 0.234187009655)
])

# Function to compute the product of all terms
def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4 for w_4
product_w4_qiskit = pauli_op_product([term1_w4, term2_w4, term3_w4, term4_w4])

# Prepare the sum as a string format
sum_string_w4 = ""
for label, coeff in product_w4_qiskit.to_list():
    # Add each term to the sum with its coefficient
    sum_string_w4 += f"({coeff}) * {label} + "

# Remove the trailing " + " from the last term
sum_string_w4 = sum_string_w4.rstrip(' + ')

# Print the resulting product as a sum of terms
print("Product of Pauli operators as a sum of terms for w_4:")
print(sum_string_w4)

# Save the result to a text file
with open('pauli_product_sum_output_w4.txt', 'w') as f:
    f.write(sum_string_w4)
# Out:
# Product of Pauli operators as a sum of terms for w_4:
# ...

# %%
# w_4 term definitions using SparsePauliOp
term1_w4 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.234187009655),
    ('ZZZZYIII', 1j * 0.234187009655),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.5),
    ('ZZZZZZYI', 1j * 0.5),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term2_w4 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.5),
    ('ZZZZYIII', 1j * 0.5),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.234187009655),
    ('ZZZZZZYI', 1j * 0.234187009655),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term3_w4 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.234187009655),
    ('ZYIIIIII', 1j * 0.234187009655),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.5),
    ('ZZZYIIII', 1j * 0.5)
])

term4_w4 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.5),
    ('ZYIIIIII', 1j * 0.5),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.234187009655),
    ('ZZZYIIII', 1j * 0.234187009655)
])




def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4
product_w4_qiskit = pauli_op_product([term1_w4, term2_w4, term3_w4, term4_w4])

# Print the resulting product as a sum of terms
print("Product of Pauli operators with coefficients for w4:")
for label, coeff in product_w4_qiskit.to_list():
    print(f"{coeff} * {label}")

# Save the result to a text file
with open('pauli_product_output_w4.txt', 'w') as f:
    for label, coeff in product_w4_qiskit.to_list():
        f.write(f"{coeff} * {label}\n")
# Out:
# Product of Pauli operators with coefficients for w4:
# (0.012711216747293252+0j) * IIIIIIII
# (0.012711216747293252-0j) * ZIIIIIII
# (-0+0.019289899685862685j) * YXIIIIII
# (-0.019289899685862685+0j) * YYIIIIII
# (-0+0.012711216747293252j) * YZXIIIII
# (-0.012711216747293252+0j) * YZYIIIII
# (-0+0.009034887847954212j) * YZZXIIII
# (-0.009034887847954212+0j) * YZZYIIII
# (-0.012711216747293252+0j) * ZIIIIIII
# (-0.012711216747293252+0j) * IIIIIIII
# (0.019289899685862685-0j) * XXIIIIII
# 0.019289899685862685j * XYIIIIII
# (0.012711216747293252-0j) * XZXIIIII
# 0.012711216747293252j * XZYIIIII
# (0.009034887847954212-0j) * XZZXIIII
# 0.009034887847954212j * XZZYIIII
# -0.009034887847954212j * YXIIIIII
# (-0.009034887847954212+0j) * XXIIIIII
# (0.013710888872787767+0j) * IIIIIIII
# (0.013710888872787767-0j) * IZIIIIII
# (-0+0.009034887847954212j) * IYXIIIII
# (-0.009034887847954212+0j) * IYYIIIII
# (-0+0.006421824129660362j) * IYZXIIII
# (-0.006421824129660362+0j) * IYZYIIII
# ...

# %%
# Computing w5

# %%
import numpy as np
from qiskit.quantum_info import SparsePauliOp

# Define the w_5 terms using SparsePauliOp
# Pauli operators are represented by strings, and the real or complex coefficients are provided separately

# w_5 term definitions using SparsePauliOp
term1_w5 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.234187009655),
    ('ZZZZZYII', 1j * 0.234187009655),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.5),
    ('ZZZZZZZY', 1j * 0.5)
])

term2_w5 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.234187009655),
    ('ZZZZYIII', 1j * 0.234187009655),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.5),
    ('ZZZZZZYI', 1j * 0.5),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term3_w5 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.5),
    ('ZYIIIIII', 1j * 0.5),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.234187009655),
    ('ZZZYIIII', 1j * 0.234187009655)
])

term4_w5 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.5),
    ('YIIIIIII', 1j * 0.5),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.234187009655),
    ('ZZYIIIII', 1j * 0.234187009655),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

# Function to compute the product of all terms
def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4 for w_5
product_w5_qiskit = pauli_op_product([term1_w5, term2_w5, term3_w5, term4_w5])

# Prepare the sum as a string format
sum_string_w5 = ""
for label, coeff in product_w5_qiskit.to_list():
    # Add each term to the sum with its coefficient
    sum_string_w5 += f"({coeff}) * {label} + "

# Remove the trailing " + " from the last term
sum_string_w5 = sum_string_w5.rstrip(' + ')

# Print the resulting product as a sum of terms
print("Product of Pauli operators as a sum of terms for w_5:")
print(sum_string_w5)

# Save the result to a text file
with open('pauli_product_sum_output_w5.txt', 'w') as f:
    f.write(sum_string_w5)
# Out:
# Product of Pauli operators as a sum of terms for w_5:
# ...

# %%
term1_w5 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.234187009655),
    ('ZZZZZYII', 1j * 0.234187009655),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.5),
    ('ZZZZZZZY', 1j * 0.5)
])

term2_w5 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.234187009655),
    ('ZZZZYIII', 1j * 0.234187009655),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.5),
    ('ZZZZZZYI', 1j * 0.5),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term3_w5 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.5),
    ('ZYIIIIII', 1j * 0.5),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.234187009655),
    ('ZZZYIIII', 1j * 0.234187009655)
])

term4_w5 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.5),
    ('YIIIIIII', 1j * 0.5),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.234187009655),
    ('ZZYIIIII', 1j * 0.234187009655),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])


def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4
product_w5_qiskit = pauli_op_product([term1_w5, term2_w5, term3_w5, term4_w5])

# Print the resulting product as a sum of terms
print("Product of Pauli operators with coefficients for w5:")
for label, coeff in product_w5_qiskit.to_list():
    print(f"{coeff} * {label}")

# Save the result to a text file
with open('pauli_product_output_w5.txt', 'w') as f:
    for label, coeff in product_w5_qiskit.to_list():
        f.write(f"{coeff} * {label}\n")
# Out:
# Product of Pauli operators with coefficients for w5:
# (0.012711216747293252+0j) * IIIIIIII
# (0.012711216747293252-0j) * ZIIIIIII
# (-0+0.008376146782924157j) * YXIIIIII
# (-0.008376146782924157+0j) * YYIIIIII
# (-0+0.005953603678250325j) * YZXIIIII
# (-0.005953603678250325+0j) * YZYIIIII
# (-0+0.008376146782924157j) * YZZXIIII
# (-0.008376146782924157+0j) * YZZYIIII
# (-0.012711216747293252+0j) * ZIIIIIII
# (-0.012711216747293252+0j) * IIIIIIII
# (0.008376146782924157-0j) * XXIIIIII
# 0.008376146782924157j * XYIIIIII
# (0.005953603678250325-0j) * XZXIIIII
# 0.005953603678250325j * XZYIIIII
# (0.008376146782924157-0j) * XZZXIIII
# 0.008376146782924157j * XZZYIIII
# -0.019289899685862685j * YXIIIIII
# (-0.019289899685862685+0j) * XXIIIIII
# (0.012711216747293252+0j) * IIIIIIII
# (0.012711216747293252-0j) * IZIIIIII
# (-0+0.009034887847954212j) * IYXIIIII
# (-0.009034887847954212+0j) * IYYIIIII
# (-0+0.012711216747293252j) * IYZXIIII
# (-0.012711216747293252+0j) * IYZYIIII
# ...

# %%
# Computing w6

# %%
import numpy as np
from qiskit.quantum_info import SparsePauliOp

# Define the w_6 terms using SparsePauliOp
# Pauli operators are represented by strings, and the real or complex coefficients are provided separately

# w_6 term definitions using SparsePauliOp
term1_w6 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.5),
    ('ZZZZZYII', 1j * 0.5),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.234187009655),
    ('ZZZZZZZY', 1j * 0.234187009655)
])

term2_w6 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.5),
    ('ZZZZYIII', 1j * 0.5),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.234187009655),
    ('ZZZZZZYI', 1j * 0.234187009655),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term3_w6 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.234187009655),
    ('ZYIIIIII', 1j * 0.234187009655),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.5),
    ('ZZZYIIII', 1j * 0.5)
])

term4_w6 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.234187009655),
    ('YIIIIIII', 1j * 0.234187009655),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.5),
    ('ZZYIIIII', 1j * 0.5),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

# Function to compute the product of all terms
def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4 for w_6
product_w6_qiskit = pauli_op_product([term1_w6, term2_w6, term3_w6, term4_w6])

# Prepare the sum as a string format
sum_string_w6 = ""
for label, coeff in product_w6_qiskit.to_list():
    # Add each term to the sum with its coefficient
    sum_string_w6 += f"({coeff}) * {label} + "

# Remove the trailing " + " from the last term
sum_string_w6 = sum_string_w6.rstrip(' + ')

# Print the resulting product as a sum of terms
print("Product of Pauli operators as a sum of terms for w_6:")
print(sum_string_w6)

# Save the result to a text file
with open('pauli_product_sum_output_w6.txt', 'w') as f:
    f.write(sum_string_w6)
# Out:
# Product of Pauli operators as a sum of terms for w_6:
# ...

# %%
# w_6 term definitions using SparsePauliOp
term1_w6 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.329478560135),
    ('ZZZZYIII', 1j * 0.329478560135),
    ('ZZZZZXII', 0.5),
    ('ZZZZZYII', 1j * 0.5),
    ('ZZZZZZXI', 0.329478560135),
    ('ZZZZZZYI', 1j * 0.329478560135),
    ('ZZZZZZZX', 0.234187009655),
    ('ZZZZZZZY', 1j * 0.234187009655)
])

term2_w6 = SparsePauliOp.from_list([
    ('ZZZZXIII', 0.5),
    ('ZZZZYIII', 1j * 0.5),
    ('ZZZZZXII', 0.329478560135),
    ('ZZZZZYII', 1j * 0.329478560135),
    ('ZZZZZZXI', 0.234187009655),
    ('ZZZZZZYI', 1j * 0.234187009655),
    ('ZZZZZZZX', 0.329478560135),
    ('ZZZZZZZY', 1j * 0.329478560135)
])

term3_w6 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.329478560135),
    ('YIIIIIII', 1j * 0.329478560135),
    ('ZXIIIIII', 0.234187009655),
    ('ZYIIIIII', 1j * 0.234187009655),
    ('ZZXIIIII', 0.329478560135),
    ('ZZYIIIII', 1j * 0.329478560135),
    ('ZZZXIIII', 0.5),
    ('ZZZYIIII', 1j * 0.5)
])

term4_w6 = SparsePauliOp.from_list([
    ('XIIIIIII', 0.234187009655),
    ('YIIIIIII', 1j * 0.234187009655),
    ('ZXIIIIII', 0.329478560135),
    ('ZYIIIIII', 1j * 0.329478560135),
    ('ZZXIIIII', 0.5),
    ('ZZYIIIII', 1j * 0.5),
    ('ZZZXIIII', 0.329478560135),
    ('ZZZYIIII', 1j * 0.329478560135)
])

# Function to compute the product of all terms
def pauli_op_product(terms):
    """Computes the product of SparsePauliOp objects."""
    result = None
    for term in terms:
        if result is None:
            result = term
        else:
            result = result.compose(term)
    return result

# Compute the full product of term1, term2, term3, and term4 for w_6
product_w6_qiskit = pauli_op_product([term1_w6, term2_w6, term3_w6, term4_w6])


# Print the resulting product as a sum of terms
print("Product of Pauli operators with coefficients for w6:")
for label, coeff in product_w6_qiskit.to_list():
    print(f"{coeff} * {label}")

# Save the result to a text file
with open('pauli_product_output_w6.txt', 'w') as f:
    for label, coeff in product_w6_qiskit.to_list():
        f.write(f"{coeff} * {label}\n")
# Out:
# Product of Pauli operators with coefficients for w6:
# (0.012711216747293252+0j) * IIIIIIII
# (0.012711216747293252-0j) * ZIIIIIII
# (-0+0.01788345731743136j) * YXIIIIII
# (-0.01788345731743136+0j) * YYIIIIII
# (-0+0.0271390303971582j) * YZXIIIII
# (-0.0271390303971582+0j) * YZYIIIII
# (-0+0.01788345731743136j) * YZZXIIII
# (-0.01788345731743136+0j) * YZZYIIII
# (-0.012711216747293252+0j) * ZIIIIIII
# (-0.012711216747293252+0j) * IIIIIIII
# (0.01788345731743136-0j) * XXIIIIII
# 0.01788345731743136j * XYIIIIII
# (0.0271390303971582-0j) * XZXIIIII
# 0.0271390303971582j * XZYIIIII
# (0.01788345731743136-0j) * XZZXIIII
# 0.01788345731743136j * XZZYIIII
# -0.009034887847954212j * YXIIIIII
# (-0.009034887847954212+0j) * XXIIIIII
# (0.012711216747293252+0j) * IIIIIIII
# (0.012711216747293252-0j) * IZIIIIII
# (-0+0.019289899685862685j) * IYXIIIII
# (-0.019289899685862685+0j) * IYYIIIII
# (-0+0.012711216747293252j) * IYZXIIII
# (-0.012711216747293252+0j) * IYZYIIII
# ...
